# %% [markdown]
# <a href="https://colab.research.google.com/github/manojDOX/Play-Store-App-Review-Analysis-EDA/blob/main/Play_Store_App_Review_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play Store App Review EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The dataset contains app details like category, ratings, size, installs, price, and user reviews. Key issues include missing values, inconsistent formats, and outliers. EDA focuses on identifying what drives app success — such as category, pricing, and user sentiment. This helps developers and businesses make informed decisions on app design, marketing, and user engagement strategies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [Play Store App Review EDA](https://github.com/manojDOX/Play-Store-App-Review-Analysis-EDA)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# App creators often lack clear insights into what drives installs, high ratings, and user engagement. Through EDA of Play Store data and reviews, we aim to identify key success factors to help developers make smarter decisions on app design, pricing, and strategy.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To analyze Play Store app data and user reviews to uncover the key factors influencing app success—such as installs, ratings, pricing, and sentiment—so that app developers and businesses can make informed, data-driven decisions to improve app quality, user engagement, and market performance.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
link1 = "https://drive.google.com/uc?export=download&id=1An_Uq3-yNU6YYirih2Wp3H8QFFQA3QvQ"
link2 = "https://drive.google.com/uc?export=download&id=1oxcJgHKawQDzceVahvJXn0NbOlYL9CDq"

# %%
# reading google drive file and storing as dataframe
data_playstore = pd.read_csv(link1)
data_review = pd.read_csv(link2)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data_playstore.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_playstore.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
data_review.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
data_review.tail(5)
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"playstore data rows: {data_playstore.shape[0]} and columns: {data_playstore.shape[1]}")
# Out:
# playstore data rows: 10841 and columns: 13

# %%
print(f"playstore review data rows: {data_review.shape[0]} and columns: {data_review.shape[1]}")
# Out:
# playstore review data rows: 64295 and columns: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data_playstore[data_playstore.duplicated(keep=False)]
# Out:
#                                                    App             Category  \
# 164                                       Ebook Reader  BOOKS_AND_REFERENCE
# 192                      Docs To Go™ Free Office Suite             BUSINESS
# 193                                 Google My Business             BUSINESS
# 204                                                Box             BUSINESS
# 213                                ZOOM Cloud Meetings             BUSINESS
# ...                                                ...                  ...
# 8643                    Wunderlist: To-Do List & Tasks         PRODUCTIVITY
# 8654   TickTick: To Do List with Reminder, Day Planner         PRODUCTIVITY
# 8658                           ColorNote Notepad Notes         PRODUCTIVITY
# 10049        Airway Ex - Intubate. Anesthetize. Train.              MEDICAL
# 10768                                             AAFP              MEDICAL
#
# ...

# %%
# Dataset Duplicate Value Count
data_review[data_review.duplicated(keep=False)]
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data_p1 = data_playstore.isnull().sum()
data_p1
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data_p2 = data_review.isnull().sum()
data_p2
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(12,6))
sns.heatmap(data_playstore.isnull().T,cbar=False, cmap="YlGnBu")
plt.title("Heatmap showing missing value")
plt.xlabel("Rows")
plt.ylabel("Columns")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data_review.isnull().T,cbar=False, cmap="YlGnBu")
plt.title("Heatmap showing missing value")
plt.xlabel("Rows")
plt.ylabel("Columns")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Play Store dataset contains some missing values. In comparison, the Review dataset appears to have a higher number of missing entries. Additionally, the Play Store dataset includes several columns with object data types that require text mining techniques. In the Review dataset, the sentiment polarity and sentiment subjectivity fields are represented as float values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data_playstore.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data_review.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
data_playstore.describe().T
# Out:
#          count      mean       std  min  25%  50%  75%   max
# Rating  9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
data_review.describe().T
# Out:
#                           count      mean       std  min       25%       50%  \
# Sentiment_Polarity      37432.0  0.182146  0.351301 -1.0  0.000000  0.150000
# Sentiment_Subjectivity  37432.0  0.492704  0.259949  0.0  0.357143  0.514286
#
#                          75%  max
# Sentiment_Polarity      0.40  1.0
# Sentiment_Subjectivity  0.65  1.0

# %%
data_playstore.select_dtypes(include='number').columns
# Out:
# Index(['Rating'], dtype='object')

# %%
data_playstore.select_dtypes(include='object').columns
# Out:
# Index(['App', 'Category', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data_review.select_dtypes(include='number').columns
# Out:
# Index(['Sentiment_Polarity', 'Sentiment_Subjectivity'], dtype='object')

# %%
data_review.select_dtypes(include='object').columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment'], dtype='object')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Play Store Data Description**
#
# * **Application Name**: The name of the mobile application.
# * **Category**: The primary category to which the app belongs (e.g., Games, Productivity, Education).
# * **Rating**: The overall user rating of the app, represented as a numeric value (e.g., 4.5).
# * **Reviews**: The total number of user reviews for the app, as recorded when the data was scraped.
# * **Size**: The size of the app file (e.g., 15MB, 50MB), as recorded when the data was scraped.
# * **Installs**: The total number of times the app has been downloaded/installed by users, as recorded when the data was scraped.
# * **Type**: The cost of the app if it is paid, represented as a numeric value (e.g., $2.99). If the app is free, the price will be 0.
# * **Price**: The cost of the app if it is paid, represented as a numeric value (e.g., $2.99). If the app is free, the price will be 0.
# * **Content Rating**: The age group the app is targeted at (e.g., Everyone, Teen, Mature 21+, Adult).
# * **Genres**: Additional categories or genres the app belongs to, apart from its main category (e.g., Musical, Family, Game).
#
# **User Reviews**
#
# * **App**: The name of the mobile application being reviewed.
# * **Translated_Review**: The user review of the app, which has been preprocessed (e.g., cleaned, tokenized) and translated into English.
# * **Sentiment**: The sentiment of the user review, categorized as Positive, Negative, or Neutral, based on text analysis.
# * **Sentiment_Polarity**: A numeric score representing the sentiment polarity of the review, ranging from -1 (most negative) to 1 (most positive).
# * **Sentiment_Subjectivity**: A numeric score indicating the subjectivity of the review, ranging from 0 (objective) to 1 (subjective), showing how subjective or opinion-based the review is.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data_playstore.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               462
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %%
for col in data_playstore.columns:
  if col not in ['App','Reviews','Last Updated','Current Ver','Last Updated','Android Ver','Size','Price','Genres']:
    print(data_playstore[col].value_counts())
    print("\n\n")
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
for col in data_review.columns:
  if col not in ['App','Translated_Review','Sentiment_Polarity','Sentiment_Subjectivity']:
    print(data_review

      [col].value_counts())
    print("\n\n")
# Out:
# Sentiment
# Positive    23998
# Negative     8271
# Neutral      5163
# Name: count, dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# #### Handeling missing value

# %%
# Handeling missing value
print(f"Percentile of missing value in rating column of playstore dataset is {data_playstore.loc[:,'Rating'].isnull().sum()/len(data_playstore)*100:.2f}%")
skew_value = data_playstore.loc[:,'Rating'].skew()
if skew_value > 0.5 and skew_value < -0.5:
  print("The value is skewed")
else:
  print("The value is normal distribution")

data_playstore["Rating"].fillna(data_playstore.loc[:,'Rating'].mean(),inplace=True)
print(f"Percentile of missing value in rating column of playstore dataset is {data_playstore.loc[:,'Rating'].isnull().sum()/len(data_playstore)*100:.2f}%")
# Out:
# Percentile of missing value in rating column of playstore dataset is 13.60%
# The value is normal distribution
# Percentile of missing value in rating column of playstore dataset is 0.00%
# /tmp/ipython-input-118-149613449.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_playstore["Rating"].fillna(data_playstore.loc[:,'Rating'].mean(),inplace=True)

# %%
data_playstore.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
data_playstore['Type'].fillna(data_playstore['Type'].mode()[0], inplace=True)
data_playstore['Content Rating'].fillna(data_playstore['Content Rating'].mode()[0], inplace=True)
data_playstore['Current Ver'].fillna(data_playstore['Current Ver'].mode()[0], inplace=True)
data_playstore['Android Ver'].fillna(data_playstore['Android Ver'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-120-911241976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_playstore['Type'].fillna(data_playstore['Type'].mode()[0], inplace=True)
# /tmp/ipython-input-120-911241976.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data_playstore.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
for col in data_review.columns:
  print(f"Percentile of missing value in rating column of playstore dataset is {data_review.loc[:,col].isnull().sum()/len(data_review)*100:.2f}%")
# Out:
# Percentile of missing value in rating column of playstore dataset is 0.00%
# Percentile of missing value in rating column of playstore dataset is 41.79%
# Percentile of missing value in rating column of playstore dataset is 41.78%
# Percentile of missing value in rating column of playstore dataset is 41.78%
# Percentile of missing value in rating column of playstore dataset is 41.78%

# %%
print(data_review.loc[:,'Sentiment'].isnull().sum())
data_review.dropna(subset=['Sentiment'],inplace=True)
print(data_review.loc[:,'Sentiment'].isnull().sum())
print(data_review.loc[:,'Sentiment_Polarity'].isnull().sum())
print(data_review.loc[:,'Sentiment_Subjectivity'].isnull().sum())
# Out:
# 26863
# 0
# 0
# 0

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))  # 1 row, 2 columns

# Plot for data_review
sns.heatmap(data_review.isnull().T, cbar=False, cmap="YlGnBu", ax=axes[0])
axes[0].set_title("Missing Values - Review Dataset")
axes[0].set_xlabel("Rows")
axes[0].set_ylabel("Columns")

# Plot for data_playstore
sns.heatmap(data_playstore.isnull().T, cbar=False, cmap="YlGnBu", ax=axes[1])
axes[1].set_title("Missing Values - Playstore Dataset")
axes[1].set_xlabel("Rows")
axes[1].set_ylabel("Columns")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Handeling Duplicates

# %%
data_playstore[data_playstore.duplicated(keep=False)].sort_values(by='App').head(5)
# Out:
#                              App            Category  Rating Reviews  Size  \
# 1393       10 Best Foods for You  HEALTH_AND_FITNESS     4.0    2490  3.8M
# 1407       10 Best Foods for You  HEALTH_AND_FITNESS     4.0    2490  3.8M
# 2543  1800 Contacts - Lens Store             MEDICAL     4.7   23160   26M
# 2322  1800 Contacts - Lens Store             MEDICAL     4.7   23160   26M
# 2256  2017 EMRA Antibiotic Guide             MEDICAL     4.4      12  3.8M
#
#         Installs  Type   Price Content Rating            Genres  \
# 1393    500,000+  Free       0   Everyone 10+  Health & Fitness
# 1407    500,000+  Free       0   Everyone 10+  Health & Fitness
# 2543  1,000,000+  Free       0       Everyone           Medical
# 2322  1,000,000+  Free       0       Everyone           Medical
# 2256      1,000+  Paid  $16.99       Everyone           Medical
#
#            Last Updated Current Ver   Android Ver
# 1393  February 17, 2017         1.9  2.3.3 and up
# ...

# %%
data_playstore.drop_duplicates(inplace=True)

# %%
data_playstore[data_playstore.duplicated(keep=False)].sort_values(by='App').count()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
data_review.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
data_review[data_review.duplicated(keep=False)].sort_values(by='App').head(10)
# Out:
#                        App                                  Translated_Review  \
# 0    10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 131  10 Best Foods for You  Thanks advice. Downloaded Adobe reader still c...
# 132  10 Best Foods for You                 No recipe book Unable recipe book.
# 133  10 Best Foods for You                     Absolutely Fabulous Phenomenal
# 134  10 Best Foods for You                                    Great Love food
# 135  10 Best Foods for You                          Excellent It really works
# 136  10 Best Foods for You                                               Best
# 137  10 Best Foods for You  WEALTH OF INFORMATION Very informative ... eas...
# 138  10 Best Foods for You                               Not description good
# 139  10 Best Foods for You                                    Great app. Love
#
#     Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# ...

# %%
data_review.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# #### data manipulation

# %%
data_playstore.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_playstore.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
print(data_playstore.dtypes['Reviews'])
# Out:
# object

# %%
# Force values to string first, then clean
data_playstore['Reviews'] = data_playstore['Reviews'].astype(str).str.replace(',', '', regex=False)

# Convert safely to numeric (invalid strings become NaN)
data_playstore['Reviews'] = pd.to_numeric(data_playstore['Reviews'], errors='coerce')

# %%
data_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          10358 non-null  float64
#  3   Reviews         10357 non-null  float64
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10358 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10358 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10358 non-null  object
#  12  Android Ver     10358 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
data_playstore['Size'].value_counts()
# Out:
# Size
# Varies with device    1526
# 11M                    188
# 13M                    186
# 12M                    186
# 14M                    182
#                       ...
# 552k                     1
# 885k                     1
# 1020k                    1
# 582k                     1
# 619k                     1
# Name: count, Length: 462, dtype: int64

# %%
import numpy as np

def cov_mk(str_v):
    try:
        s1 = str_v[-1]  # Last character
        n1 = float(str_v[:-1])  # Numeric part

        if s1 == 'M':
            return n1 * 1_000_000
        elif s1 == 'k':
            return n1 * 1_000
        elif s1 == '+':
            return n1
        else:
            return float(str_v)  # Try parsing full string
    except (ValueError, TypeError, IndexError):
        return np.nan

# %%
data_playstore['Size'] = data_playstore['Size'].apply(cov_mk)
data_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          10358 non-null  float64
#  3   Reviews         10357 non-null  float64
#  4   Size            8831 non-null   float64
#  5   Installs        10358 non-null  object
#  6   Type            10358 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10358 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10358 non-null  object
#  12  Android Ver     10358 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %%
(data_playstore.loc[:,'Size'].isnull().sum())/(len(data_playstore))*100
# Out:
# np.float64(14.742228229387914)

# %%
data_playstore.loc[:,'Size'].skew()
# Out:
# np.float64(1.5698488236184072)

# %%
data_playstore.loc[:,'Size'] = data_playstore.loc[:,'Size'].fillna(data_playstore.loc[:,'Size'].median())

# %%
(data_playstore.loc[:,'Size'].isnull().sum())/(len(data_playstore))*100
# Out:
# np.float64(0.0)

# %%
def cov_ins(data):
  try:
    data = data[0:-1]
    a = data.replace(',', '')
    a = int(a)
    return a
  except (ValueError,TypeError,IndexError):
    return 0

# %%
data_playstore.loc[:,'Installs'] = data_playstore.loc[:,'Installs'].apply(cov_ins)

# %%
data_playstore['Installs'] = data_playstore['Installs'].astype(str).astype(float)

# %%
data_playstore['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
def cov_pri(data):
  try:
    if data == '0'or data == 'Everyone':
      return 0
    str1=data[1:len(data)]
    return float(str1)
  except (ValueError,TypeError,IndexError):
    print(data)
    return np.nan

# %%
data_playstore['Price'] = data_playstore['Price'].apply(cov_pri)

# %%
data_playstore['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10358, dtype: object

# %%
data_playstore['Last Updated'] = pd.to_datetime(data_playstore['Last Updated'],format='%B %d, %Y',errors='coerce')

# %%
def con_gen_sub(data):
  if ";" in data:
    a = data.split(';')
    return a[1]
  else:
    return np.nan

# %%
def con_gen(data):
  if ";" in data:
    a = data.split(';')
    return a[0]
  else:
    return data

# %%
data_playstore['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
data_playstore['Genres_subcategory'] = data_playstore['Genres'].apply(con_gen_sub)

# %%
data_playstore['Genres'] = data_playstore['Genres'].apply(con_gen)

# %%
data_playstore['Genres'].value_counts()
# Out:
# Genres
# Tools                      843
# Entertainment              628
# Education                  610
# Business                   427
# Medical                    408
# Productivity               407
# Personalization            388
# Lifestyle                  374
# Action                     371
# Sports                     368
# Communication              367
# Finance                    360
# Photography                322
# Health & Fitness           308
# Social                     280
# News & Magazines           264
# Casual                     263
# Travel & Local             237
# Arcade                     234
# Books & Reference          233
# Shopping                   224
# Simulation                 216
# Dating                     196
# Video Players & Editors    178
# Puzzle                     162
# Maps & Navigation          137
# Food & Drink               124
# Role Playing               120
# Racing                     119
# Strategy                   109
# ...

# %%
data_playstore['Year'] = data_playstore['Last Updated'].dt.year

# %%
data_playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 10358 non-null  object
#  1   Category            10358 non-null  object
#  2   Rating              10358 non-null  float64
#  3   Reviews             10357 non-null  float64
#  4   Size                10358 non-null  float64
#  5   Installs            10358 non-null  float64
#  6   Type                10358 non-null  object
#  7   Price               10358 non-null  float64
#  8   Content Rating      10358 non-null  object
#  9   Genres              10358 non-null  object
#  10  Last Updated        10357 non-null  datetime64[ns]
#  11  Current Ver         10358 non-null  object
#  12  Android Ver         10358 non-null  object
#  13  Genres_subcategory  462 non-null    object
#  14  Year                10357 non-null  float64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure(figsize=(14,6))
sns.countplot(y='Category', data=data_playstore, order=data_playstore['Category'].value_counts().index)
plt.title('Number of Apps in Each Category')
plt.xlabel('Number of Apps')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The horizontal bar chart clearly shows category-wise app counts and handles long category names without clutter.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# FAMILY has the most apps, followed by GAME and TOOLS.
#
# Categories like BEAUTY, COMICS, and PARENTING have the fewest apps.
#
# Some professional categories (e.g., BUSINESS, MEDICAL) have moderate presence.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Highlights saturated vs. untapped categories, guiding better app strategy.
#
# Negative: Entering crowded categories may lower visibility and growth without unique features.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,6))
sns.histplot(data_playstore['Rating'], bins=30, kde=True)
plt.title('Distribution of App Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with KDE curve clearly shows how app ratings are distributed, highlighting central tendency and spread.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most app ratings are clustered between 4.0 and 5.0.
#
# Few apps have ratings below 3.0 or above 5.0.
#
# There are some extreme outliers (e.g., ratings above 10), which are likely data errors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Maintaining ratings above 4.0 is crucial for visibility and downloads.
#
# Negative: Outliers may mislead analysis—cleaning data is essential for accurate insights.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
fig = px.scatter(data_playstore,
                 x='Reviews', y='Rating',
                 size='Installs', color='Category',
                 hover_name='App',
                 size_max=60,
                 log_x=True,
                 title='Bubble Chart: Rating vs Reviews (Bubble Size = Installs)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bubble chart shows the relationship between ratings, reviews, and installs (via bubble size) across categories—great for multivariable comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Apps with more reviews generally have higher installs (larger bubbles).
#
# Most high-rated apps lie between 4.0 to 4.7.
#
# A few apps have low ratings but high installs, indicating potential user dissatisfaction despite popularity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Encourages focusing on user satisfaction and reviews to boost installs.
#
# Negative: High installs with low ratings may harm brand image—indicates the need for app improvement.

# %% [markdown]
# #### Chart - 4

# %%
data_playstore['Size'].head(5)
# Out:
# 0    19000000.0
# 1    14000000.0
# 2     8700000.0
# 3    25000000.0
# 4     2800000.0
# Name: Size, dtype: float64

# %%
data_playstore=data_playstore[(data_playstore.loc[:,'Rating'])<10]

# %%
# Chart - 4 visualization code
from matplotlib.ticker import FuncFormatter

# Create a formatter function to convert to MB
def mb_formatter(x, pos):
    return f'{x / 1e6:.0f}MB'

plt.figure(figsize=(12, 6))
sns.histplot(data=data_playstore, x='Size', y='Rating', bins=40, cmap='YlGnBu')

# Format the x-axis
plt.gca().xaxis.set_major_formatter(FuncFormatter(mb_formatter))

plt.title('2D Histogram: App Size vs Rating')
plt.xlabel('App Size')
plt.ylabel('Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A 2D histogram helps visualize how two continuous variables—app size and rating—are related by showing density patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most highly rated apps (4.0–4.5) are below 20MB.
#
# Larger apps (>40MB) tend to have fewer high ratings.
#
# There's no clear advantage in making apps very large in size.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Developers should aim to optimize app size to improve user satisfaction and ratings.
#
# Negative: Larger app sizes may lead to lower ratings, especially in regions with limited storage or slow internet.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
top_genres = data_playstore.groupby('Genres')['Rating'].mean().sort_values(ascending=False).head(10)
top_genres.plot(kind='barh', figsize=(10,6), title='Top 10 Genres by Average Rating')
plt.xlabel('Average Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is ideal to compare average ratings across multiple genres clearly and quickly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Education, Board, and Arcade genres have the highest average ratings.
#
# All top 10 genres maintain ratings above 4.4, showing strong user satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Genres like Education and Board games offer opportunities for quality-focused apps.
#
# No Negative Insight: All listed genres show high satisfaction—good areas for app development.

# %% [markdown]
# #### Chart - 7

# %%
fig = px.pie(data_playstore,
             names='Content Rating',
             title='Pie Chart: Content Rating Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart clearly shows the proportion of each content rating type and makes the dominant category easy to identify.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 81% of apps are rated "Everyone", showing a focus on family-friendly content.
#
# Very few apps target adults (18+) or are unrated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Apps suitable for all ages have wider reach and monetization potential.
#
# Negative: Limited presence in adult-targeted categories could mean missed niche opportunities.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,6))
sns.countplot(x='Year', data=data_playstore)
plt.title('Number of Apps Updated by Year')
plt.xlabel('Year')
plt.ylabel('App Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart is perfect for showing trends over time, making it easy to compare app updates year by year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Huge spike in app updates in 2018.
#
# Steady growth from 2014 to 2017, with sharp acceleration in 2018.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Indicates rising awareness of app maintenance and improvements, which can improve user experience and retention.
#
# No direct negative impact, but developers who don’t update may fall behind competitors.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10,6))
sns.heatmap(data_playstore[['Rating', 'Reviews', 'Size', 'Installs', 'Price']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap makes it easy to visualize relationships between multiple numeric variables at once.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Strongest correlation: Installs and Reviews (0.63) — more installs lead to more reviews.
#
# Weak or no correlation between Rating and other variables.
#
# Price has almost zero or negative correlation with everything.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive: Focus on increasing installs and reviews to drive visibility.
#
# Negative: Pricing does not influence ratings, installs, or reviews — free or well-priced apps win user trust better.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
pivot = data_playstore.pivot_table(values='Rating',
                                    index='Category',
                                    columns='Content Rating',
                                    aggfunc='mean')

fig = go.Figure(data=go.Heatmap(
        z=pivot.values,
        x=pivot.columns,
        y=pivot.index,
        colorscale='YlOrRd'))

fig.update_layout(title='Average Rating: Category vs Content Rating',
                  xaxis_title='Content Rating',
                  yaxis_title='Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
fig = px.sunburst(data_playstore.dropna(subset=['Genres_subcategory']),
                  path=['Genres', 'Genres_subcategory'],
                  values='Rating',
                  color='Rating',
                  color_continuous_scale='RdYlGn',
                  title='Sunburst Chart: Ratings Across Genres and Subcategories')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
fig = px.scatter(data_playstore,
                 x='Size', y='Rating',
                 size='Price', color='Category',
                 hover_name='App',
                 size_max=40,
                 title='Bubble Chart: Rating vs Size (Bubble = Price)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
fig = px.histogram(data_playstore,
                   x='Rating', nbins=40,
                   color='Content Rating',
                   title='Interactive Histogram of App Ratings')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
yearly_counts = data_playstore['Year'].value_counts().sort_index()

fig = px.line(x=yearly_counts.index,
              y=yearly_counts.values,
              labels={'x':'Year', 'y':'App Count'},
              title='Line Plot: Number of Apps Updated per Year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
